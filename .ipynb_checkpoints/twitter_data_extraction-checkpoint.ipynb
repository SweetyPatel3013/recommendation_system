# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import tweepy
import re
import emoji
import nltk
nltk.download('words')
words = set(nltk.corpus.words.words())
stopword = nltk.corpus.stopwords.words('english')

import glob
import string
# Out:
# [nltk_data] Downloading package words to C:\Users\SweetY
# [nltk_data]     pAtel\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!

# %%
movieInfoFile = 'data_files/u.item'
movieInfo = pd.read_csv(movieInfoFile, sep="|", header=None, index_col=False,
                  names=['itemId','title'], usecols=[0,1])
movieInfo
# Out:
#       itemId                                      title
# 0          1                           Toy Story (1995)
# 1          2                           GoldenEye (1995)
# 2          3                          Four Rooms (1995)
# 3          4                          Get Shorty (1995)
# 4          5                             Copycat (1995)
# ...      ...                                        ...
# 1677    1678                          Mat' i syn (1997)
# 1678    1679                           B. Monkey (1998)
# 1679    1680                       Sliding Doors (1998)
# 1680    1681                        You So Crazy (1994)
# 1681    1682  Scream of Stone (Schrei aus Stein) (1991)
#
# [1682 rows x 2 columns]

# %%
movieInfo['year'] = movieInfo.title.str.extract('(\(\d\d\d\d\))',expand=False)
movieInfo['year'] = movieInfo.year.str.extract('(\d\d\d\d)',expand=False)

#Removing the years from the 'title' column
movieInfo['title'] = movieInfo.title.str.replace('(\(\d\d\d\d\))', '')
# Out:
# <ipython-input-3-2d0fe1d6a320>:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   movieInfo['title'] = movieInfo.title.str.replace('(\(\d\d\d\d\))', '')

# %%
movieInfo
# Out:
#       itemId                                title  year
# 0          1                           Toy Story   1995
# 1          2                           GoldenEye   1995
# 2          3                          Four Rooms   1995
# 3          4                          Get Shorty   1995
# 4          5                             Copycat   1995
# ...      ...                                  ...   ...
# 1677    1678                          Mat' i syn   1997
# 1678    1679                           B. Monkey   1998
# 1679    1680                       Sliding Doors   1998
# 1680    1681                        You So Crazy   1994
# 1681    1682  Scream of Stone (Schrei aus Stein)   1991
#
# [1682 rows x 3 columns]

# %%
movieInfo['tagword'] = movieInfo['title'].str.lower()
movieInfo['tagword'] = movieInfo.tagword.str.replace(' ', '')
movieInfo['tagword'] = movieInfo['tagword'].apply(lambda x: "{}{}".format('#', x))
movieInfo['tagword'] = movieInfo.tagword.str.replace('(\([A-Za-z0-9_]+\))', '')
movieInfo
# Out:
# <ipython-input-20-657f3eff8acf>:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   movieInfo['tagword'] = movieInfo.tagword.str.replace('(\([A-Za-z0-9_]+\))', '')
#       itemId                                title  year         tagword
# 0          1                           Toy Story   1995       #toystory
# 1          2                           GoldenEye   1995      #goldeneye
# 2          3                          Four Rooms   1995      #fourrooms
# 3          4                          Get Shorty   1995      #getshorty
# 4          5                             Copycat   1995        #copycat
# ...      ...                                  ...   ...             ...
# 1677    1678                          Mat' i syn   1997       #mat'isyn
# 1678    1679                           B. Monkey   1998       #b.monkey
# 1679    1680                       Sliding Doors   1998   #slidingdoors
# 1680    1681                        You So Crazy   1994     #yousocrazy
# 1681    1682  Scream of Stone (Schrei aus Stein)   1991  #screamofstone
#
# [1682 rows x 4 columns]

# %%
movieInfo['title'][47]
# Out:
# 'Hoop Dreams '

# %%
api_key = "0Nfp0QdlOHXy5FVWtI8T7xdct"
api_secret = "7IMXzjvfbStJejs1iI2B75esFcGehySRvWil31ZKGl48yNfr9E"
access_token = "1354846100847550467-Lelq383ZqoVZDlRTyj9BfmVkWNyWyU"
access_secret = "vqAMs6mi3oQpkwboh554koYc1e3ScEXbBdyGRqRV2E1Q5"

# %%
auth = tweepy.OAuthHandler(api_key, api_secret)
auth.set_access_token(access_token, access_secret)
api = tweepy.API(auth)

# %%
# function to perform data extraction
def scrape(movieID, movie_title, words):
    numtweet = 100  
    
    # Creating DataFrame using pandas
    db = pd.DataFrame(columns=['Movie Id', 'Title', 'Tagword', 'description', 'totaltweets', 'retweetcount', 'text', 'hashtags'])
      
    # We are using .Cursor() to search through twitter for the required tweets.
    # The number of tweets can be restricted using .items(number of tweets)
    tweets = tweepy.Cursor(api.search, q=words, lang="en",
                           tweet_mode='extended').items(numtweet)
     
    # .Cursor() returns an iterable object. Each item in 
    # the iterator has various attributes that you can access to 
    # get information about each tweet
    list_tweets = [tweet for tweet in tweets]
      
    # Counter to maintain Tweet Count
    i = 1  
      
    # we will iterate over each tweet in the list for extracting information about each tweet
    for tweet in list_tweets:
        movie_id = movieID
        title = movie_title
        tagword = words
        description = tweet.user.description
        totaltweets = tweet.user.statuses_count
        retweetcount = tweet.retweet_count
        hashtags = tweet.entities['hashtags']
          
        # Retweets can be distinguished by a retweeted_status attribute,
        # in case it is an invalid reference, except block will be executed
        try:
            text = tweet.retweeted_status.full_text
        except AttributeError:
            text = tweet.full_text
        hashtext = list()
        for j in range(0, len(hashtags)):
            hashtext.append(hashtags[j]['text'])
          
        # Here we are appending all the extracted information in the DataFrame
        ith_tweet = [movie_id, title, tagword, description,
                     totaltweets, retweetcount, text, hashtext]
        db.loc[len(db)] = ith_tweet
          
        # Function call to print tweet data on screen
#         print(ith_tweet)
        i = i+1
    filename = str(movie_title) + '_tweets.csv'
      
    # we will save our database as a CSV file.
    db.to_csv('movie_tweets_collected/' + filename)

# %%
for index, row in movieInfo[91:].iterrows():
    movieID = row['itemId']
    movie_title = row['title']
    movie_tagword = row['tagword']
    scrape(movieID, movie_title, movie_tagword)

# %% [markdown]
# # Working with the collected Tweets.....

# %%
# specifying the path to csv files
path = "movie_tweets_collected"
  
# csv files in the path
files = glob.glob(path + "/*.csv")
  
print(len(files))
  
# defining an empty list to store 
# content
data_frame = pd.DataFrame()
content = []
  
# checking all the csv files in the 
# specified path
for filename in files:
    
    # reading content of csv file
    # content.append(filename)
    df = pd.read_csv(filename, index_col=None)
    content.append(df)

    
# converting content to data frame
data_frame = pd.concat(content)
# Out:
# 85

# %%
data_frame
# Out:
#    Unnamed: 0 Movie Id                     Title                Tagword  \
# 0           0       28                Apollo 13               #apollo13
# 1           1       28                Apollo 13               #apollo13
# 2           2       28                Apollo 13               #apollo13
# 3           3       28                Apollo 13               #apollo13
# 4           4       28                Apollo 13               #apollo13
# ..        ...      ...                       ...                    ...
# 92         92       66  While You Were Sleeping   #whileyouweresleeping
# 93         93       66  While You Were Sleeping   #whileyouweresleeping
# 94         94       66  While You Were Sleeping   #whileyouweresleeping
# 95         95       66  While You Were Sleeping   #whileyouweresleeping
# 96         96       66  While You Were Sleeping   #whileyouweresleeping
#
#                                           description totaltweets  \
# 0   I’m a theatre kid who loves space. Proud Democ...        5153
# 1   Poet, Storyteller... at least trying to tell one.        1877
# 2   An open source bot here to support all women w...      462150
# 3   👩‍💻 Our mission is to inspire you to excel in ...        1906
# 4   Log On http://t.co/Jd5OkgIQ3e And Stay Updated...       36243
# ..                                                ...         ...
# 92  Always contrary.  No Dms please. I am Proficie...      398858
# 93  Do not lead me down this road unless you’re su...       29899
# 94  Woof, Woof, Grrrrr. 🐾🐺🍖🍗\nI eat Noms | random ...       28346
# 95                       simple in all aspect of life        1013
# 96                                Bae Suzy Contents ♡          36
#
#    retweetcount                                               text  \
# 0             8  Final surprise for #Apollo13 celebrations. The...
# 1             0  @noursafeialdin @FilmstoFilms_ One of my all t...
# 2             1  🎥 On #MovieMonday, we highlight movies that ha...
# 3             1  🎥 On #MovieMonday, we highlight movies that ha...
# 4             0  @StevenDaGuy - Trill [ https://t.co/RLoE9yo3dq...
# ..          ...                                                ...
# 92            3  WAKE UP JORDY!! @J_Mei21\n\nYou gotta know wha...
# 93            3  WAKE UP JORDY!! @J_Mei21\n\nYou gotta know wha...
# 94            0  @kpopxkdramas #whileyouweresleeping to me it i...
# 95           10  Funny Moment from While You Were Sleeping kdra...
# 96            1  She is too cute to handle ☺️\n\n#SUZY #BaeSuzy...
#
#                                              hashtags
# 0                                        ['Apollo13']
# 1                                        ['Apollo13']
# 2                                     ['MovieMonday']
# 3   ['MovieMonday', 'womenwhocode', 'Apollo13', 'J...
# 4                                        ['Apollo13']
# ..                                                ...
# 92   ['Scheming', 'Sneaking', 'WhileYouWereSleeping']
# 93  ['Scheming', 'Sneaking', 'WhileYouWereSleeping...
# 94                           ['whileyouweresleeping']
# 95                              ['kdrama', 'kdramas']
# 96  ['SUZY', 'BaeSuzy', 'NamHongJoo', 'whileyouwer...
#
# [3960 rows x 9 columns]

# %%
def cleaner(tweet):
    # Remove @ sign
    tweet = re.sub("@[A-Za-z0-9]+","",tweet)
    
    # Remove http links
    tweet = re.sub(r"(?:\@|http?\://|https?\://|www)\S+", "", tweet)
    
    # Join the sub strings generated from re.sub
#     tweet = " ".join(tweet.split())
    
    # Remove puncutations
    tweet  = "".join([char for char in tweet if char not in string.punctuation])
    tweet = re.sub('[0-9]+', '', tweet)
    
    # Remove Emojis
    tweet = ''.join(c for c in tweet if c not in emoji.UNICODE_EMOJI)
    regrex_pattern = re.compile(pattern = "["
                                u"\U0001F600-\U0001F64F"  # emoticons
                                u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                                u"\U0001F680-\U0001F6FF"  # transport & map symbols
                                u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                                u"\U00002702-\U000027B0"
                                u"\U000024C2-\U0001F251"
                                u"\U00002500-\U00002BEF"  # chinese char
                                u"\U00002702-\U000027B0"
                                u"\U00002702-\U000027B0"
                                u"\U000024C2-\U0001F251"
                                u"\U0001f926-\U0001f937"
                                u"\U00010000-\U0010ffff"
                                u"\u2640-\u2642"
                                u"\u2600-\u2B55"
                                u"\u200d"
                                u"\u23cf"
                                u"\u23e9"
                                u"\u231a"
                                u"\ufe0f"  # dingbats
                                u"\u3030"
                               "]+", flags = re.UNICODE)
    tweet = regrex_pattern.sub(r'',tweet)
    
    # Remove hashtag sign and keep the text
    tweet = tweet.replace("#", "").replace("_", " ")
    
    #tokenize
    tweet = " ".join(w for w in nltk.wordpunct_tokenize(tweet) \
         if w.lower() in words or not w.isalpha())
    
    return tweet

# %%
for index, row in data_frame.iterrows():
    desc = data_frame['description'][index].values
    desc = " ".join(str(i) for i in desc)
#     print(desc)
    clean_desc = cleaner(desc)
    row['cleaned tweet'] = clean_desc
    print(row)
    break
# Out:
# Unnamed: 0                                                       0
# Movie Id                                                        28
# Title                                                   Apollo 13
# Tagword                                                  #apollo13
# description      I’m a theatre kid who loves space. Proud Democ...
# totaltweets                                                   5153
# retweetcount                                                     8
# text             Final surprise for #Apollo13 celebrations. The...
# hashtags                                              ['Apollo13']
# cleaned tweet    I ’ m a who space Democratic Artist Painter Ar...
# Name: 0, dtype: object

# %%
t = data_frame['description'][0]

# %%
type(t)
# Out:
# pandas.core.series.Series

# %%
arr_t = t.values
arr_t[0]
# Out:
# 'I’m a theatre kid who loves space. Proud Democratic, Artist, Painter, Perler beads Artist, nice Jewish girl , space nerd'

# %%
print(cleaner(arr_t[2]))
# Out:
# just a year old boy who just to be happy
